# %%
for i in range(6): 
    if i == 3:
     continue
print (i)
# Out:
# 5

# %%
x=6
while x>0:
    print (x)
    x-=1
# Out:
# 6
# 5
# 4
# 3
# 2
# 1

# %%
def info_user(nam : str,age : int)->str:
    '''
this function will....capitalize 
Arges: 
     name(str): name of user
     age(int): age of user
     returns:
     str :name and age
    '''
    return f"my name is {nam} and my age {age}"

    print (info_user("amit", 20))

# %%
info_user(age=30 ,nam ="depi")
# Out:
# 'my name is depi and my age 30'

# %%
def fuc_1(**name):
    print (name)
    print(type(name))

# %%
fuc_1(depi="r5",depi2="r5")
# Out:
# {'depi': 'r5', 'depi2': 'r5'}
# <class 'dict'>

# %%
def train_model(model_name,*dataset,**hyperparameters):
    print (f"training model:{model_name}")
    print ("\n hypeparameter")
    for dataset in datasets:
        print ("-",dataset)
        print ("\nhyperparameter")
        for key ,value in hyperparameters.items():
            print (f"{key}): {value}")
            train_model(
                "froadaction",
                "train.csv",
                "vaildation",
                "test.csv",
            
            learning_rate=0.001,
epochs=100,
batch_size=64,
optimizer="adam",
early_stopping=true,)

# %%
def sum(x):
    return x+10
sum

# %%
sum_1=lambda x:x+10
print(type(sum_1))
# Out:
# <class 'function'>

# %%
transformers = {
    "lower": lambda text:text.lower(),
    "upper" :lambda text:text.upper(),
}
text = " machine learning"
print (transformers {"strip"{text}})
# Out:
#   Cell In[43], line 6
#     print (transformers {"strip"{text}})
#                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
